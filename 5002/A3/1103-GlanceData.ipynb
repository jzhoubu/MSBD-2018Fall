# %%
import sys
from PIL import Image
sys.path.append("B:\XAI-Project\src")
from VIS import *

# %%
filename="00017.jpg"
img=Image.open("./images/"+filename)
vis=VIS(img,'resnet152')


vis.ClassActivationMaps(topk=1)
#vis.output[1].save('5002A3_00000_cam.png')
vis.plot()


vis.GuidedBackPropagation(type='gray')
res=Image.fromarray(vis.output[1]).resize(np.array(img).shape[:2][::-1])
#res.save('5002A3_00000_gbp.png')
vis.plot()
# Out:
# #### Fetching model <resnet152> from torchvision #########
# #### Fetching classes from amazon ########################
# #### Preprocessing image for imagenet model ##############
# #### Predicting image ####################################
#   0.501 -> silky terrier, Sydney silky
# #### Generating images ###################################
# #### Predicting image ####################################
#   0.501 -> silky terrier, Sydney silky
# #### Generating images ###################################

# %%
filename="00032.jpg"
img=Image.open("./images/"+filename)
vis=VIS(img,'resnet152')


vis.ClassActivationMaps(topk=1)
#vis.output[1].save('5002A3_00000_cam.png')
vis.plot()


vis.GuidedBackPropagation(type='gray')
res=Image.fromarray(vis.output[1]).resize(np.array(img).shape[:2][::-1])
#res.save('5002A3_00000_gbp.png')
vis.plot()
# Out:
# #### Fetching model <resnet152> from torchvision #########
# #### Fetching classes from amazon ########################
# #### Preprocessing image for imagenet model ##############
# #### Predicting image ####################################
#   0.758 -> whippet
# #### Generating images ###################################
# #### Predicting image ####################################
#   0.758 -> whippet
# #### Generating images ###################################

# %%
filename="00000.jpg"
img=Image.open("./images/"+filename)
vis=VIS(img,'resnet152')


vis.ClassActivationMaps(topk=1)
vis.output[1].save('5002A3_00000_cam.png')
vis.plot()


vis.GuidedBackPropagation(type='gray')
res=Image.fromarray(vis.output[1]).resize(np.array(img).shape[:2][::-1])
res.save('5002A3_00000_gbp.png')
vis.plot()
# Out:
# #### Fetching model <resnet152> from torchvision #########
# #### Fetching classes from amazon ########################
# #### Preprocessing image for imagenet model ##############
# #### Predicting image ####################################
#   0.798 -> black stork, Ciconia nigra
# #### Generating images ###################################
# #### Predicting image ####################################
#   0.798 -> black stork, Ciconia nigra
# #### Generating images ###################################

# %%
filename="00001.jpg"
img=Image.open("./images/"+filename)
vis=VIS(img,'resnet152')


vis.ClassActivationMaps(topk=1)
vis.output[1].save('5002A3_00001_cam.png')
vis.plot()


vis.GuidedBackPropagation(type='gray')
res=Image.fromarray(vis.output[1]).resize(np.array(img).shape[:2][::-1])
res.save('5002A3_00001_gbp.png')
vis.plot()
# Out:
# #### Fetching model <resnet152> from torchvision #########
# #### Fetching classes from amazon ########################
# #### Preprocessing image for imagenet model ##############
# #### Predicting image ####################################
#   0.709 -> patio, terrace
# #### Generating images ###################################
# #### Predicting image ####################################
#   0.709 -> patio, terrace
# #### Generating images ###################################

# %%
filename="00002.jpg"
img=Image.open("./images/"+filename)
vis=VIS(img,'resnet152')


vis.ClassActivationMaps(topk=1)
vis.output[1].save('5002A3_00002_cam.png')
vis.plot()


vis.GuidedBackPropagation(type='gray')
res=Image.fromarray(vis.output[1]).resize(np.array(img).shape[:2][::-1])
res.save('5002A3_00002_gbp.png')
vis.plot()
# Out:
# #### Fetching model <resnet152> from torchvision #########
# #### Fetching classes from amazon ########################
# #### Preprocessing image for imagenet model ##############
# #### Predicting image ####################################
#   0.443 -> kite
# #### Generating images ###################################
# #### Predicting image ####################################
#   0.443 -> kite
# #### Generating images ###################################
